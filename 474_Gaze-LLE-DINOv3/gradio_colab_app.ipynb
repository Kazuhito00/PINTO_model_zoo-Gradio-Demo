# %% [markdown]
# # パッケージインストール（Install Packages）

# %%
# !pip install -q onnx onnxruntime-gpu gradio

# %% [markdown]
# # 重みダウンロード（Download Weights）

# %%
# !wget https://raw.githubusercontent.com/PINTO0309/PINTO_model_zoo/refs/heads/main/474_Gaze-LLE-DINOv3/download.sh

# %%
# !source download.sh

# %% [markdown]
# # Gradioアプリ起動（Run the Gradio App）

# %%
# !wget https://raw.githubusercontent.com/Kazuhito00/PINTO_model_zoo-Gradio-Demo/refs/heads/main/474_Gaze-LLE-DINOv3/gradio_app.py

# %%
# !python gradio_app.py
