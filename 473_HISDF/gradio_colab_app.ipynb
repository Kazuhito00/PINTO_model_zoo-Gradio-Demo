# %% [markdown]
# # パッケージインストール（Install Packages）

# %%
# !pip install -q onnx onnxruntime-gpu gradio

# %% [markdown]
# # 重みダウンロード（Download Weights）

# %%
# !wget https://raw.githubusercontent.com/PINTO0309/PINTO_model_zoo/refs/heads/main/473_HISDF/download_n.sh
# !wget https://raw.githubusercontent.com/PINTO0309/PINTO_model_zoo/refs/heads/main/473_HISDF/download_pico.sh
# !wget https://raw.githubusercontent.com/PINTO0309/PINTO_model_zoo/refs/heads/main/473_HISDF/download_s.sh
# !wget https://raw.githubusercontent.com/PINTO0309/PINTO_model_zoo/refs/heads/main/473_HISDF/download_x.sh

# %%
# ダウンロード時間がかかるため、必要に応じてコメントアウトを外す
# Since downloading takes time, uncomment it only when needed.
# !source download_n.sh  # 2824M
# !source download_pico.sh  # 2722M
# !source download_s.sh  # 3130M
# !source download_x.sh  # 15G

# %% [markdown]
# # Gradioアプリ起動（Run the Gradio App）

# %%
# !wget https://raw.githubusercontent.com/Kazuhito00/PINTO_model_zoo-Gradio-Demo/refs/heads/main/473_HISDF/gradio_app.py

# %%
# !python gradio_app.py
