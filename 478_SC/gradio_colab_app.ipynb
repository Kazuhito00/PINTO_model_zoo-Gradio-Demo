# %% [markdown]
# # パッケージインストール

# %%
# !pip install -q onnx onnxruntime-gpu gradio bbalg

# %% [markdown]
# # 重みダウンロード

# %%
# !wget https://raw.githubusercontent.com/PINTO0309/PINTO_model_zoo/refs/heads/main/478_SC/download.sh -O download_sc.sh
# !wget https://raw.githubusercontent.com/PINTO0309/PINTO_model_zoo/refs/heads/main/472_DEIMv2-Wholebody34/download.sh -O download_deimv2.sh

# %%
# !source download_sc.sh
# !source download_deimv2.sh

# %% [markdown]
# # Gradioアプリ起動

# %%
# !wget https://raw.githubusercontent.com/Kazuhito00/PINTO_model_zoo-Gradio-Demo/refs/heads/main/478_SC/gradio_app.py

# %%
# !python gradio_app.py
